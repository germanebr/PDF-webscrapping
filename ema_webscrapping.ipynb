# %% [markdown]
# # Loading main EMA page

# %%
import os
import time
import requests
from bs4 import BeautifulSoup

# %%
BASE_PATH = "C:/Users/"

BASE_URL = "https://www.ema.europa.eu/"
MAIN_PAGE = "en/medicines/human/EPAR/"

# %% [markdown]
# # Base functions

# %%
def try_get_request(url, tries=1, max_tries=5):
    done = False

    while (tries <= max_tries) and (not done):
        response = requests.get(url)

        if response.status_code == 200:
            done = True
        else:
            print(f"\t>>> Failed to get content. Waiting {tries*5} seconds to retry...")
            time.sleep(tries*5)
            tries += 1
    
    return response

# %%
def download_pdf(store_path, id, soup):
    results = soup.find(id=id)

    elements = results.find_all("a",
                            class_ = "standalone align-self-top d-inline-block mt-3-5 mt-md-0 flex-shrink-0",
                            href = True)
    urls = [BASE_URL + element['href'] for element in elements]
    
    print(f"\t>>> Found {len(urls)} documents.")

    for url in urls:
        name = url.rsplit('/', 1)[1]
        if not name.endswith('.pdf'):
            name = name.split('.pdf')
            name = '('.join(name) + ').pdf'
        
        pdf_path = os.path.join(store_path, name)
        response = try_get_request(url)

        if response.status_code == 200:
            with open(pdf_path, 'wb') as file:
                file.write(response.content)
            print(f"\t>>> {name} downloaded succesfully!")
        else:
            print("\t>>> Unable to extract the content.")
        time.sleep(2)

# %% [markdown]
# # Get the documents from the main page

# %% [markdown]
# The PDF documents are distributed on different ids:
# * Medicine overview and risk-management plan summaries -> **id = "ema-inpage-item-overview"**
# * Product information -> **id = "ema-inpage-item-product-info"**
# * Assessment history -> **id = "ema-inpage-item-assessment-history"**
# * More information on the drug -> **id = "ema-inpage-item-related-medicines"**

# %%
def get_ema_docs(drug_name):
    # Create a folder for the drug documents
    print("Creating drug folder")
    path = os.path.join(BASE_PATH, drug_name)
    if not os.path.isdir(path):
        os.mkdir(path)
    print(f"\t>>> Done!")

    # Get the main EMA webpage content
    print(f"Reading {drug_name} main page")
    page = try_get_request(BASE_URL + MAIN_PAGE + drug_name)
    soup = BeautifulSoup(page.content, "html.parser")
    print(f"\t>>> Done!")

    # Extract medicine overview
    print("Downloading medicine overview documents")
    id = "ema-inpage-item-overview"
    download_pdf(path, id, soup)
    print(f"\t>>> Done!")

    # Extract product information
    print("Downloading product information documents")
    id = "ema-inpage-item-product-info"
    download_pdf(path, id, soup)
    print(f"\t>>> Done!")

    # Extract documents of changes
    print("Downloading documents of assessment history")
    id = "ema-inpage-item-assessment-history"
    download_pdf(path, id, soup)
    print(f"\t>>> Done!")

    # Read the additional information of the drug
    print("Downloading paediatric investigation plans")
    id = "ema-inpage-item-related-medicines"
    results = soup.find(id=id)
    elements = results.find_all("a",
                                href = True)
    urls = [BASE_URL + element['href'] for element in elements]
    print(f"\t>>> Found {len(urls)} additional links.")

    for url in urls:
        sub_page = try_get_request(url)
        sub_soup = BeautifulSoup(sub_page.content, "html.parser")
        sub_id = "ema-inpage-item-decision"
        download_pdf(path, sub_id, sub_soup)
    print(f"\t>>> Done!")

    print("EMA documents completed!")

# %%
drug_names = ["stelara", "tremfya"]

for drug_name in drug_names:
    print(f"Looking for EMA documents on {drug_name}:")
    get_ema_docs(drug_name)
    print()
# Out:
# Looking for EMA documents on stelara:
# Creating drug folder
# 	>>> Done!
# Reading stelara main page
# 	>>> Done!
# Downloading medicine overview documents
# 	>>> Found 2 documents.
# 	>>> stelara-epar-medicine-overview_en.pdf downloaded succesfully!
# 	>>> stelara-epar-risk-management-plan-summary_en.pdf downloaded succesfully!
# 	>>> Done!
# Downloading product information documents
# 	>>> p-0401-2022-ema-decision-9-september-2022-acceptance-modification-agreed-paediatric-investigation-plan-ustekinumab-stelara-emea-000311-pip04-13-m05_en.pdf downloaded succesfully!
# 	>>> Found 1 documents.
# 	>>> p00842021-ema-decision-19-march-2021-acceptance-modification-agreed-paediatric-investigation-plan-ustekinumab-stelara-emea-000311-pip05-17-m02_en.pdf downloaded succesfully!
# 	>>> Found 1 documents.
# 	>>> p01782019-ema-decision-15-may-2019-agreement-paediatric-investigation-plan-and-granting-deferral-and-granting-waiver-ustekinumab-stelara-emea-000311-pip06-18_en.pdf downloaded succesfully!
# 	>>> Done!
#
# Looking for EMA documents on tremfya:
# Creating drug folder
# 	>>> Done!
# Reading tremfya main page
# 	>>> Done!
# Downloading medicine overview documents
# 	>>> Found 2 documents.
# 	>>> tremfya-epar-medicine-overview_en.pdf downloaded succesfully!
# 	>>> tremfya-epar-risk-management-plan-summary_en.pdf downloaded succesfully!
# 	>>> Done!
# Downloading product information documents
# 	>>> Found 2 documents.
# 	>>> tremfya-epar-product-information_en.pdf downloaded succesfully!
# 	>>> tremfya-epar-all-authorised-presentations_en.pdf downloaded succesfully!
# 	>>> Done!
# Downloading documents of assessment history
# 	>>> Found 5 documents.
# 	>>> Failed to get content. Waiting 5 seconds to retry...
# 	>>> Failed to get content. Waiting 10 seconds to retry...
# 	>>> tremfya-epar-procedural-steps-taken-and-scientific-information-after-authorisation_en.pdf downloaded succesfully!
# 	>>> tremfya-h-c-4271-ii-17-epar-assessment-report-variation_en.pdf downloaded succesfully!
# 	>>> Failed to get content. Waiting 5 seconds to retry...
# 	>>> chmp-post-authorisation-summary-positive-opinion-tremfya-ii-17_en.pdf downloaded succesfully!
# 	>>> Failed to get content. Waiting 5 seconds to retry...
# 	>>> tremfya-epar-public-assessment-report_en.pdf downloaded succesfully!
# 	>>> chmp-summary-positive-opinion-tremfya_en.pdf downloaded succesfully!
# 	>>> Done!
# Downloading paediatric investigation plans
# 	>>> Found 4 additional links.
# ['https://www.ema.europa.eu//en/medicines/human/paediatric-investigation-plans/emea-001523-pip02-14-m02', 'https://www.ema.europa.eu//en/medicines/human/paediatric-investigation-plans/emea-001523-pip03-18-m02', 'https://www.ema.europa.eu//en/medicines/human/paediatric-investigation-plans/emea-001523-pip05-19-m01', 'https://www.ema.europa.eu//en/medicines/human/paediatric-investigation-plans/emea-001523-pip04-19-m02']
# 	>>> Found 1 documents.
# 	>>> p01292018-ema-decision-11-april-2018-acceptance-modification-agreed-paediatric-investigation-plan-guselkumab-tremfya-emea-001523-pip02-14-m02_en.pdf downloaded succesfully!
# 	>>> Found 1 documents.
# 	>>> Failed to get content. Waiting 5 seconds to retry...
# 	>>> p-0435-2022-ema-decision-28-october-2022-acceptance-modification-agreed-paediatric-investigation-plan-guselkumab-tremfya-emea-001523-pip03-18-m02_en.pdf downloaded succesfully!
# 	>>> Failed to get content. Waiting 5 seconds to retry...
# 	>>> Found 1 documents.
# 	>>> Failed to get content. Waiting 5 seconds to retry...
# 	>>> p00652022-ema-decision-11-march-2022-acceptance-modification-agreed-paediatric-investigation-plan-guselkumab-tremfya-emea-001523-pip05-19-m01_en.pdf downloaded succesfully!
# 	>>> Failed to get content. Waiting 5 seconds to retry...
# 	>>> Found 1 documents.
# 	>>> Failed to get content. Waiting 5 seconds to retry...
# 	>>> p-0190-2023-ema-decision-15-may-2023-acceptance-modification-agreed-paediatric-investigation-plan-guselkumab-tremfya-emea-001523-pip04-19-m02_en.pdf downloaded succesfully!
# 	>>> Done!
